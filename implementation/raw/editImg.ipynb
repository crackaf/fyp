# %%
from PIL import Image
import numpy as np

# %%
imagename="lena_embedded.png"

# %%
lena = Image.open(imagename).convert("L")
lena
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F19412C3AC0>

# %%
lena.mode
# Out:
# 'L'

# %%
img = np.array(lena)

# %%
img.shape
# Out:
# (512, 512)

# %%
startx=260
starty=260
width=10
height=10
# startx=0
# starty=0
# width=4
# height=4

for i in range(width):
    for j in range(height):
        img[startx+i][starty+j]=0
        
Image.fromarray(img, 'L')
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F1964FFF2B0>

# %%
Image.fromarray(img, 'L').save("lena_embedded_edited.png")
