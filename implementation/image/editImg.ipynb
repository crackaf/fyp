# %%
from PIL import Image
import numpy as np

# %%
imagename="boat_watermarked.png"

# %%
lena = Image.open(imagename).convert("L")
lena
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F0F6CE6DEB0>

# %%
lena.mode
# Out:
# 'L'

# %%
img = np.array(lena)

# %%
img.shape
# Out:
# (512, 512)

# %%
x=511//2
img[x-0][x-0]=0
img[x-0][x-1]=0
img[x-1][x-0]=0
img[x-1][x-1]=0

# %%
Image.fromarray(img, 'L')
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F0F6CE6DE80>

# %%
Image.fromarray(img, 'L').save("boat_watermarked_edited1.png")
